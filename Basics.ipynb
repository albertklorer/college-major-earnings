# %% [markdown]
# # College Major Earnings
#
# Data visualizations based on job outcomes of students who graduated college between 2010 and 2012.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import pandas as pd
from pandas.plotting import scatter_matrix

# %%
# load in data and preview 
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# 0      ...              270                  1207          37
# 1      ...              170                   388          85
# 2      ...              133                   340          16
# 3      ...              150                   692          40
# 4      ...             5180                 16697        1672
#
#    Unemployment_rate  Median  P25th   P75th  College_jobs  Non_college_jobs  \
# 0           0.018381  110000  95000  125000          1534               364
# 1           0.117241   75000  55000   90000           350               257
# 2           0.024096   73000  50000  105000           456               176
# 3           0.050125   70000  43000   80000           529               102
# 4           0.061098   65000  50000   75000         18314              4440
#
#    Low_wage_jobs
# 0            193
# 1             50
# 2              0
# 3              0
# 4            972
#
# [5 rows x 21 columns]

# %%
# generate summary statistics for numeric columns
for column in ['Total', 'Men', 'Women', 'Rank', 'Sample_size', 'Median', 'Low_wage_jobs', 'Full_time', 'Part_time']:
    print(column)
    print(recent_grads[column].describe())
    print()
# Out:
# Total
# count       172.000000
# mean      39370.081395
# std       63483.491009
# min         124.000000
# 25%        4549.750000
# 50%       15104.000000
# 75%       38909.750000
# max      393735.000000
# Name: Total, dtype: float64
#
# Men
# count       172.000000
# mean      16723.406977
# std       28122.433474
# min         119.000000
# 25%        2177.500000
# 50%        5434.000000
# 75%       14631.000000
# max      173809.000000
# Name: Men, dtype: float64
#
# Women
# count       172.000000
# mean      22646.674419
# std       41057.330740
# min           0.000000
# 25%        1778.250000
# 50%        8386.500000
# 75%       22553.750000
# max      307087.000000
# Name: Women, dtype: float64
#
# Rank
# count    173.000000
# mean      87.000000
# std       50.084928
# min        1.000000
# 25%       44.000000
# 50%       87.000000
# 75%      130.000000
# max      173.000000
# Name: Rank, dtype: float64
#
# Sample_size
# count     173.000000
# mean      356.080925
# std       618.361022
# min         2.000000
# 25%        39.000000
# 50%       130.000000
# 75%       338.000000
# max      4212.000000
# Name: Sample_size, dtype: float64
#
# Median
# count       173.000000
# mean      40151.445087
# std       11470.181802
# min       22000.000000
# 25%       33000.000000
# 50%       36000.000000
# 75%       45000.000000
# max      110000.000000
# Name: Median, dtype: float64
#
# Low_wage_jobs
# count      173.000000
# mean      3859.017341
# std       6944.998579
# min          0.000000
# 25%        340.000000
# 50%       1231.000000
# 75%       3466.000000
# max      48207.000000
# Name: Low_wage_jobs, dtype: float64
#
# Full_time
# count       173.000000
# mean      26029.306358
# std       42869.655092
# min         111.000000
# 25%        3154.000000
# 50%       10048.000000
# 75%       25147.000000
# max      251540.000000
# Name: Full_time, dtype: float64
#
# Part_time
# count       173.000000
# mean       8832.398844
# std       14648.179473
# min           0.000000
# 25%        1030.000000
# 50%        3299.000000
# 75%        9948.000000
# max      115172.000000
# Name: Part_time, dtype: float64

# %%
# drop rows with missing columns
raw_data_count = len(recent_grads)
recent_grads = recent_grads.dropna()
cleaned_data_count = len(recent_grads)

print(raw_data_count - cleaned_data_count, 'columns deleted')
# Out:
# 1 columns deleted

# %%
# sample size v median
ax = recent_grads.plot(x='Sample_size', y='Median', kind='scatter')
ax.set_title('Sample_size vs. Median')

# %%
# sample size v unemployment rate
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax.set_title('Sample_size vs. Unemployment_rate')

# %%
# full time v median
ax = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax.set_title('Full_time vs. Median')

# %%
# share women v unemployment rate
ax = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax.set_title('ShareWomen vs. Unemployment_rate')

# %%
# men v median
ax = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax.set_title('Men vs. Median')

# %%
# women v median
ax = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax.set_title('Women vs. Median')

# %%
# visualize distribtutions
columns = ['Sample_size', 'Median', 'Employed', 'Full_time', 'ShareWomen',
    'Unemployment_rate', 'Men', 'Women']

fig, axs = plt.subplots(len(columns), 1, figsize=(8, 25))
for i in range(len(columns)):
    axs[i].hist(recent_grads[columns[i]], bins=20)
    axs[i].set_title(columns[i])

# %%
# scatter matrix of sample size and median
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed946518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed06ce80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed4ec3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed23d630>]],
#       dtype=object)

# %%
# scatter matrix of sample size, median, and unemployment rate
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed2256a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ee19bda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed6ea780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed657908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ee1e8710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed0c0240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed142978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed079400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe7ed0e95f8>]],
#       dtype=object)
